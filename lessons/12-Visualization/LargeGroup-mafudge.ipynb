# %% [markdown]
# # Code Samples From Large Group
#
# Place your notes and code samples from large group here.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import folium
import random 
from IPython.display import display
from ipywidgets import interact_manual

# %%
df = pd.read_csv("https://raw.githubusercontent.com/mafudge/datasets/master/exam-scores/exam-scores.csv")
df.sample(10)
# Out:
#    Class_Section Exam_Version  Completion_Time Made_Own_Study_Guide  \
# 29           M02            A               20                    N
# 49           M02            C               30                    N
# 0            M01            A               20                    N
# 58           M02            D               25                    N
# 14           M01            C               20                    Y
# 62           M02            D               45                    ?
# 32           M02            A               35                    ?
# 12           M01            B               35                    Y
# 43           M02            B               45                    N
# 30           M02            A               25                    ?
#
#    Did_Exam_Prep Assignment Studied_In_Groups  Student_Score Percentage  \
# 29                        N                 N             16     53.30%
# 49                        Y                 Y             24     80.00%
# ...

# %%
sns.barplot(df,x="Exam_Version",y="Student_Score")
# Out:
# <Axes: xlabel='Exam_Version', ylabel='Student_Score'>

# %%
sns.barplot(df,x="Exam_Version",y="Student_Score", errorbar=None, estimator="count")
# Out:
# <Axes: xlabel='Exam_Version', ylabel='Student_Score'>

# %%
display("Count of Student Exams by version")
display(sns.barplot(df,x="Exam_Version",y="Student_Score", errorbar=None, estimator="count"))
# Out:
# 'Count of Student Exams by version'
# <Axes: xlabel='Exam_Version', ylabel='Student_Score'>

# %%
df.head(3)
# Out:
#   Class_Section Exam_Version  Completion_Time Made_Own_Study_Guide  \
# 0           M01            A               20                    N
# 1           M01            A               20                    ?
# 2           M01            A               30                    Y
#
#   Did_Exam_Prep Assignment Studied_In_Groups  Student_Score Percentage  \
# 0                        N                 Y             24     80.00%
# 1                        ?                 ?             27     90.00%
# 2                        Y                 Y             30    100.00%
#
#   Letter_Grade
# 0            B
# 1           A-
# 2            A

# %%
# class average score by section
sns.barplot(df, x = "Student_Score", y = "Class_Section", estimator="mean", errorbar=None)
# Out:
# <Axes: xlabel='Student_Score', ylabel='Class_Section'>

# %%
# same but add exam version with class section
sns.barplot(df, x = "Student_Score", y = "Class_Section", estimator="mean", errorbar=None, hue="Exam_Version")
# Out:
# <Axes: xlabel='Student_Score', ylabel='Class_Section'>

# %%
df.sample(3)
# Out:
#    Class_Section Exam_Version  Completion_Time Made_Own_Study_Guide  \
# 7            M01            B               15                    Y
# 21           M01            D               25                    N
# 9            M01            B               20                    Y
#
#    Did_Exam_Prep Assignment Studied_In_Groups  Student_Score Percentage  \
# 7                         Y                 Y             26     86.70%
# 21                        N                 Y             15     50.00%
# 9                         Y                 N             27     90.00%
#
#    Letter_Grade
# 7            B+
# 21            D
# 9            A-

# %%
sns.lineplot(df, x = "Completion_Time", y="Student_Score")
# Out:
# <Axes: xlabel='Completion_Time', ylabel='Student_Score'>

# %%
sns.lineplot(df, x = "Completion_Time", y="Student_Score", errorbar=None)
# Out:
# <Axes: xlabel='Completion_Time', ylabel='Student_Score'>

# %%
sns.scatterplot(df, x = "Completion_Time", y="Student_Score")
# Out:
# <Axes: xlabel='Completion_Time', ylabel='Student_Score'>

# %%
df.head()
# Out:
#   Class_Section Exam_Version  Completion_Time Made_Own_Study_Guide  \
# 0           M01            A               20                    N
# 1           M01            A               20                    ?
# 2           M01            A               30                    Y
# 3           M01            A               50                    N
# 4           M01            A               55                    Y
#
#   Did_Exam_Prep Assignment Studied_In_Groups  Student_Score Percentage  \
# 0                        N                 Y             24     80.00%
# 1                        ?                 ?             27     90.00%
# 2                        Y                 Y             30    100.00%
# 3                        Y                 Y             18     60.00%
# 4                        Y                 N             24     80.00%
#
#   Letter_Grade
# 0            B
# 1           A-
# 2            A
# 3           C-
# 4            B

# %%
import pandas as pd
x = [ { 'a' :2, 'b' : 'x', 'c' : 10}, 
      { 'a' :4, 'b' : 'y', 'c' : 3},
      { 'a' :1, 'b' : 'x', 'c' : 6} ]
y = pd.DataFrame(x)
y
# Out:
#    a  b   c
# 0  2  x  10
# 1  4  y   3
# 2  1  x   6

# %%
y.loc[y["b"]=='x', ["a","c"]]
# Out:
#    a   c
# 0  2  10
# 2  1   6

# %%
y.loc[
    y["b"]=='x', 
    ["a","c"]
]

# %%
import folium

# %%
# geocoding is the process of converting a location to a global corrdinate lat, lon

# %%
syr=(42.98, -76.30) # 43.0495° N, 76.1474° W
my_map = folium.Map(syr, zoom_start=7)
cities = pd.read_csv("ny-cities.csv").dropna()

# %%
# loop over dataframe create marker and put on map
for i, row in cities.iterrows():
    location = (row["lat"], row["lng"])
    marker = folium.Marker(location, popup=row["location"])
    marker.add_to(my_map)

# %%
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
