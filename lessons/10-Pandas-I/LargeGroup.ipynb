# %% [markdown]
# # Code Samples From Large Group
#
# Place your notes and code samples from large group here.

# %%
import pandas as pd
import numpy as np

# %%
data =  [
    { "product": "pizza", "qty": 100, "price": 19.99 },
    { "product": "beer", "qty": 50, "price": 14.99 },
    { "product": "soda", "qty": 75, "price" : 11.99 }
]

# %%
data[-1]["price"]
# Out:
# 11.99

# %%
data[0].get("beer", 0)
# Out:
# 0

# %%
items = pd.DataFrame(data)  # constructor method (list[dict] variable)

# %%
items
# Out:
#   product  qty  price
# 0   pizza  100  19.99
# 1    beer   50  14.99
# 2    soda   75  11.99

# %%
# Index numberd row ID
# column names in col
# Series in all index values in a single column

# %%
items["qty"]
# Out:
# 0    100
# 1     50
# 2     75
# Name: qty, dtype: int64

# %%
items["price"]
# Out:
# 0    19.99
# 1    14.99
# 2    11.99
# Name: price, dtype: float64

# %%
items["product"]
# Out:
# 0    pizza
# 1     beer
# 2     soda
# Name: product, dtype: object

# %%
items
# Out:
#   product  qty  price
# 0   pizza  100  19.99
# 1    beer   50  14.99
# 2    soda   75  11.99

# %%
items[:1]
# Out:
#   product  qty  price
# 0   pizza  100  19.99

# %%
items[0:2]
# Out:
#   product  qty  price
# 0   pizza  100  19.99
# 1    beer   50  14.99

# %%
items[1:3]
# Out:
#   product  qty  price
# 1    beer   50  14.99
# 2    soda   75  11.99

# %%
items[-1:]
# Out:
#   product  qty  price
# 2    soda   75  11.99

# %%
items["qty"]
# Out:
# 0    100
# 1     50
# 2     75
# Name: qty, dtype: int64

# %%
items
# Out:
#   product  qty  price
# 0   pizza  100  19.99
# 1    beer   50  14.99
# 2    soda   75  11.99

# %%
items.iloc[0:2,0:2] #dont use this, its for nerds
# Out:
#   product  qty
# 0   pizza  100
# 1    beer   50

# %%
items.loc[0:1,["product":"price"]] #includes the upper bound here.
# Out:
#   product  qty  price
# 0   pizza  100  19.99
# 1    beer   50  14.99

# %%
items.loc[0:1,"product":"price"] #includes the upper bound here.
# Out:
#   product  qty  price
# 0   pizza  100  19.99
# 1    beer   50  14.99

# %%
# this plucks out specifc rows and columns
items.loc[ [0,2], ["product", "price"] ]
# Out:
#   product  price
# 0   pizza  19.99
# 2    soda  11.99

# %% [markdown]
# items

# %%
items
# Out:
#   product  qty  price
# 0   pizza  100  19.99
# 1    beer   50  14.99
# 2    soda   75  11.99

# %%
beer_price = items.loc[1,"price"] # get one item and its price

# %%
print(beer_price)
# Out:
# 14.99

# %%
items
# Out:
#   product  qty  price
# 0   pizza  100  19.99
# 1    beer   50  14.99
# 2    soda   75  11.99

# %%
# adds a new column
items["total"] = items["qty"] * items["price"]

# %%
items
# Out:
#   product  qty  price    total
# 0   pizza  100  19.99  1999.00
# 1    beer   50  14.99   749.50
# 2    soda   75  11.99   899.25

# %%
items["tax"] = 0.08 * items["total"]
items
# Out:
#   product  qty  price    total     tax
# 0   pizza  100  19.99  1999.00  159.92
# 1    beer   50  14.99   749.50   59.96
# 2    soda   75  11.99   899.25   71.94

# %%
# import pandas as pd

# %%
# !pip install openpyxl

# %%
prices_df = pd.read_excel("prices.xlsx")
prices_df
# Out:
#     name  price
# 0  pizza  10.99
# 1  juice   2.99
# 2  candy   4.99

# %%
products_df = pd.read_csv("products.csv")
products_df
# Out:
#      name  price
# 0   apple   1.99
# 1    pear   2.99
# 2  orange   3.99
# 3    milk   1.59

# %%
sdf = pd.read_csv("super.csv")
sdf
# Out:
#     Unnamed: 0  Year                                      Title   Comic  \
# 0            0  1978                                   Superman      DC
# 1            1  1980                                Superman II      DC
# 2            2  1982                                Swamp Thing      DC
# 3            3  1983                               Superman III      DC
# 4            4  1984                                  Supergirl      DC
# 5            5  1986                            Howard the Duck  Marvel
# 6            6  1987           Superman IV: The Quest for Peace      DC
# 7            7  1989                                     Batman      DC
# 8            8  1989                  The Return of Swamp Thing      DC
# 9            9  1989                               The Punisher  Marvel
# 10          10  1992                             Batman Returns      DC
# 11          11  1995                             Batman Forever      DC
# ...

# %%
# head, tail, sample, slice
sdf.head(5)
# Out:
#    Unnamed: 0  Year         Title Comic  IMDB Score  RT Score  \
# 0           0  1978      Superman    DC         7.3        95
# 1           1  1980   Superman II    DC         6.7        88
# 2           2  1982   Swamp Thing    DC         5.3        60
# 3           3  1983  Superman III    DC         4.9        24
# 4           4  1984     Supergirl    DC         4.2         8
#
#    Composite Score  Opening Weekend  Box Office  Avg Ticket Price  \
# 0             84.0                    7465343.0              2.34
# 1             77.5                   14100523.0              2.69
# 2             56.5                          NaN              2.94
# 3             36.5                   13352357.0              3.15
# 4             25.0                    5738249.0              3.36
#
#    Opening Weekend Attendance  US Population That Year
# 0                 3190317.521                222584545
# 1                 5241830.112                227224681
# ...

# %%
sdf.tail(5)
# Out:
#     Unnamed: 0  Year                             Title   Comic  IMDB Score  \
# 44          44  2011                X-Men: First Class  Marvel         7.9
# 45          45  2012             Marvel's The Avengers  Marvel         8.7
# 46          46  2012             The Dark Knight Rises      DC         9.1
# 47          47  2012  Ghost Rider: Spirit of Vengeance  Marvel         4.5
# 48          48  2012            The Amazing Spider-Man  Marvel         7.6
#
#     RT Score  Composite Score  Opening Weekend  Box Office  Avg Ticket Price  \
# 44        87             83.0                   55101604.0              7.93
# 45        92             89.5                  207438708.0              7.92
# 46        86             88.5                  160887295.0              7.92
# 47        17             31.0                   22115334.0              7.92
# 48        74             75.0                   62004688.0              7.92
#
# ...

# %%
sdf.sample(5)
# Out:
#     Unnamed: 0  Year                  Title   Comic  IMDB Score  RT Score  \
# 13          13  1997                  Steel      DC         2.7        12
# 39          39  2010             Iron Man 2  Marvel         7.1        74
# 44          44  2011     X-Men: First Class  Marvel         7.9        87
# 35          35  2008               Iron Man  Marvel         7.9        94
# 46          46  2012  The Dark Knight Rises      DC         9.1        86
#
#     Composite Score  Opening Weekend  Box Office  Avg Ticket Price  \
# 13             19.5                     870068.0              4.59
# 39             72.5                  128122480.0              7.89
# 44             83.0                   55101604.0              7.93
# 35             86.5                   98618668.0              7.18
# 46             88.5                  160887295.0              7.92
#
#     Opening Weekend Attendance  US Population That Year
# 13                1.895573e+05                267783607
# ...

# %%
sdf.sample(5)
# Out:
#     Unnamed: 0  Year                             Title   Comic  IMDB Score  \
# 14          14  1998                             Blade  Marvel         7.0
# 12          12  1997                    Batman & Robin      DC         3.6
# 33          33  2008                   The Dark Knight      DC         8.9
# 47          47  2012  Ghost Rider: Spirit of Vengeance  Marvel         4.5
# 8            8  1989         The Return of Swamp Thing      DC         3.9
#
#     RT Score  Composite Score  Opening Weekend  Box Office  Avg Ticket Price  \
# 14        55             62.5                   17073856.0              4.69
# 12        12             24.0                   42872605.0              4.59
# 33        94             91.5                  158411483.0              7.18
# 47        17             31.0                   22115334.0              7.92
# 8         40             39.5                          NaN              3.97
#
# ...

# %%
sdf[3:8]
# Out:
#    Unnamed: 0  Year                             Title   Comic  IMDB Score  \
# 3           3  1983                      Superman III      DC         4.9
# 4           4  1984                         Supergirl      DC         4.2
# 5           5  1986                   Howard the Duck  Marvel         4.3
# 6           6  1987  Superman IV: The Quest for Peace      DC         3.6
# 7           7  1989                            Batman      DC         7.6
#
#    RT Score  Composite Score  Opening Weekend  Box Office  Avg Ticket Price  \
# 3        24             36.5                   13352357.0              3.15
# 4         8             25.0                    5738249.0              3.36
# 5        16             29.5                    5070136.0              3.71
# 6        10             23.0                    5683122.0              3.91
# 7        71             73.5                   40489746.0              3.97
#
#    Opening Weekend Attendance  US Population That Year
# ...

# %%
# pandas filter
sdf[ sdf["Comic"]== "Marvel" ]
# Out:
#     Unnamed: 0  Year                                      Title   Comic  \
# 5            5  1986                            Howard the Duck  Marvel
# 9            9  1989                               The Punisher  Marvel
# 14          14  1998                                      Blade  Marvel
# 15          15  2000                                      X-Men  Marvel
# 16          16  2002                                   Blade II  Marvel
# 17          17  2002                                 Spider-Man  Marvel
# 18          18  2003                                  Daredevil  Marvel
# 19          19  2003                                       Hulk  Marvel
# 20          20  2003                                         X2  Marvel
# 21          21  2004                             Blade: Trinity  Marvel
# 23          23  2004                               Spider-Man 2  Marvel
# 24          24  2004                               The Punisher  Marvel
# ...

# %%
# Marvel movies with a IMDB Score > 8
marvel = sdf[ sdf["Comic"] == "Marvel" ]
final = marvel[ marvel["IMDB Score"] > 8 ]
final
# Out:
#     Unnamed: 0  Year                  Title   Comic  IMDB Score  RT Score  \
# 45          45  2012  Marvel's The Avengers  Marvel         8.7        92
#
#     Composite Score  Opening Weekend  Box Office  Avg Ticket Price  \
# 45             89.5                  207438708.0              7.92
#
#     Opening Weekend Attendance  US Population That Year
# 45                 26191756.06                314055984

# %%
# Marvel movies with a IMDB Score > 8
marvel = sdf[ sdf["Comic"] == "Marvel" ]
goodscore = marvel[ marvel["IMDB Score"] > 8 ]
final = goodscore[ ["Year", "Title", "Comic", "IMDB Score"] ]
final
# Out:
#     Year                  Title   Comic  IMDB Score
# 45  2012  Marvel's The Avengers  Marvel         8.7

# %%
# your one-liner
final = sdf[ (sdf["Comic"] == "Marvel") & (sdf["IMDB Score"] > 8)][ ["Year", "Title", "Comic", "IMDB Score"] ]
final
# Out:
#     Year                  Title   Comic  IMDB Score
# 45  2012  Marvel's The Avengers  Marvel         8.7

# %%
sdf
# Out:
#     Unnamed: 0  Year                                      Title   Comic  \
# 0            0  1978                                   Superman      DC
# 1            1  1980                                Superman II      DC
# 2            2  1982                                Swamp Thing      DC
# 3            3  1983                               Superman III      DC
# 4            4  1984                                  Supergirl      DC
# 5            5  1986                            Howard the Duck  Marvel
# 6            6  1987           Superman IV: The Quest for Peace      DC
# 7            7  1989                                     Batman      DC
# 8            8  1989                  The Return of Swamp Thing      DC
# 9            9  1989                               The Punisher  Marvel
# 10          10  1992                             Batman Returns      DC
# 11          11  1995                             Batman Forever      DC
# ...

# %%
sdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   49 non-null     int64
#  1   Year                         49 non-null     int64
#  2   Title                        49 non-null     object
#  3   Comic                        49 non-null     object
#  4   IMDB Score                   49 non-null     float64
#  5   RT Score                     49 non-null     int64
#  6   Composite Score              49 non-null     float64
#  7   Opening Weekend  Box Office  46 non-null     float64
#  8   Avg Ticket Price             49 non-null     float64
#  9   Opening Weekend Attendance   46 non-null     float64
#  10  US Population That Year      49 non-null     int64
# dtypes: float64(5), int64(4), object(2)
# memory usage: 4.3+ KB

# %%
sdf.describe()
# Out:
#        Unnamed: 0         Year  IMDB Score   RT Score  Composite Score  \
# count    49.00000    49.000000   49.000000  49.000000        49.000000
# mean     24.00000  2001.326531    6.212245  53.204082        57.663265
# std      14.28869     9.764706    1.530201  29.643001        21.815368
# min       0.00000  1978.000000    2.700000   8.000000        19.500000
# 25%      12.00000  1997.000000    5.300000  26.000000        39.500000
# 50%      24.00000  2004.000000    6.400000  59.000000        62.500000
# 75%      36.00000  2008.000000    7.400000  79.000000        75.000000
# max      48.00000  2012.000000    9.100000  95.000000        91.500000
#
#        Opening Weekend  Box Office  Avg Ticket Price  \
# count                 4.600000e+01         49.000000
# mean                  5.620126e+07          5.963061
# std                   4.760047e+07          1.667506
# min                   8.700680e+05          2.340000
# 25%                   1.622806e+07          4.590000
# ...

# %%
sdf[["IMDB Score", "RT Score", "Opening Weekend Attendance"]].corr()
# Out:
#                             IMDB Score  RT Score  Opening Weekend Attendance
# IMDB Score                    1.000000  0.871679                    0.644008
# RT Score                      0.871679  1.000000                    0.642934
# Opening Weekend Attendance    0.644008  0.642934                    1.000000

# %%
sdf[["IMDB Score", "RT Score"]].corr()
